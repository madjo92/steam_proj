# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs

# %%
options = webdriver.ChromeOptions()
options.headless = True

driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver',options=options)
def get_names_one_page():
    url= 'https://www.nba.com/players'
    driver.get(url)

    soup = bs(driver.page_source, 'lxml')
    #div = soup.find('div', class_= 'LeagueRoster_table__1FGIF')
    div=soup.find('tbody')
    td = div.find_all('td', class_='primary text RosterRow_primaryCol__19xPQ')
    for a in td:
          print(a.text)

get_names_one_page()            
#print(driver.page_source)
driver.close()
# Out:
# <ipython-input-30-9ea61d609752>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver',options=options)
# PreciousAchiuwa
# StevenAdams
# BamAdebayo
# SantiAldama
# LaMarcusAldridge
# NickeilAlexander-Walker
# GraysonAllen
# JarrettAllen
# JoseAlvarado
# KyleAnderson
# GiannisAntetokounmpo
# ThanasisAntetokounmpo
# CarmeloAnthony
# ColeAnthony
# OGAnunoby
# TrevorAriza
# D.J.Augustin
# DeniAvdija
# JoelAyayi
# DeandreAyton
# UdokaAzubuike
# MarvinBagley III
# LaMeloBall
# LonzoBall
# MoBamba
# DesmondBane
# DalanoBanton
# HarrisonBarnes
# ScottieBarnes
# RJBarrett
# WillBarton
# CharlesBassey
# KeitaBates-Diop
# NicolasBatum
# KentBazemore
# DariusBazley
# BradleyBeal
# MalikBeasley
# DeAndre'Bembry
# DavisBertans
# PatrickBeverley
# SaddiqBey
# KhemBirch
# GogaBitadze
# NemanjaBjelica
# EricBledsoe
# KeljinBlevins
# BogdanBogdanovic
# ...

# %%
options = webdriver.ChromeOptions()
options.headless = True

driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver',options=options)
def get_names_and_links_one_page():
    url= 'https://www.nba.com/players'
    driver.get(url)

    soup = bs(driver.page_source, 'lxml')
    #div = soup.find('div', class_= 'LeagueRoster_table__1FGIF')
    div=soup.find('tbody')
    td = div.find_all('td', class_='primary text RosterRow_primaryCol__19xPQ')
    for t in td:
        print(t.text)
        a=t.find('a')
        print(a['href'])
        

get_names_and_links_one_page()           
#print(driver.page_source)
driver.close()
# Out:
# <ipython-input-23-68a68053547f>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver',options=options)
# PreciousAchiuwa
# /player/1630173/precious-achiuwa/
# StevenAdams
# /player/203500/steven-adams/
# BamAdebayo
# /player/1628389/bam-adebayo/
# SantiAldama
# /player/1630583/santi-aldama/
# LaMarcusAldridge
# /player/200746/lamarcus-aldridge/
# NickeilAlexander-Walker
# /player/1629638/nickeil-alexander-walker/
# GraysonAllen
# /player/1628960/grayson-allen/
# JarrettAllen
# /player/1628386/jarrett-allen/
# JoseAlvarado
# /player/1630631/jose-alvarado/
# KyleAnderson
# /player/203937/kyle-anderson/
# GiannisAntetokounmpo
# /player/203507/giannis-antetokounmpo/
# ThanasisAntetokounmpo
# /player/203648/thanasis-antetokounmpo/
# CarmeloAnthony
# /player/2546/carmelo-anthony/
# ColeAnthony
# /player/1630175/cole-anthony/
# OGAnunoby
# ...

# %%
def get_detail_info_for_one_player(url):
    driver.get(url)
    soup = bs(driver.page_source, 'lxml')
    div = soup.find('div', class_='flex justify-center py-3 lg:justify-between lg:py-0')

    div_pts = div.find('div', class_='PlayerSummary_playerStat__lQ86Y')
    div_reb = div.find('div', class_='player-stats__reb')
    div_ast = div.find('div', class_='player-stats__ast')
    div_pie = div.find('div', class_='player-stats__pie')

    stat = {}
    stat['pts'] = div_pts.text.replace('PTS','').replace('\n','')
    stat['reb'] = div_reb.text.replace('REB','').replace('\n','')
    stat['ast'] = div_ast.text.replace('AST','').replace('\n','')
    stat['pie'] = div_pie.text.replace('PIE','').replace('\n','')

    return stat

def get_all_name_and_detail_link():
    url= 'https://www.nba.com/players'
    driver.get(url)

    soup = bs(driver.page_source, 'lxml')
    div=soup.find('tbody')
    td = div.find_all('td', class_='primary text RosterRow_primaryCol__19xPQ')
    players = []

    for t in td:
        player = {}
        player['name'] = t.text
        player['link'] = 'https://www.nba.com' + t.find('a')['href']
        
        stat = get_detail_info_for_one_player(player['link'])
        player['stat'] = stat

        print('name : ', player['name'])
        print('link : ',player['link'])
        print('pts : ', stat['pts'])
        print('reb : ', stat['reb'])
        print('ast : ', stat['ast'])
        print('pie : ', stat['pie'])

        print('\n')

        players.append(player)
    
    return players





get_all_name_and_detail_link()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-33-252ebec27038> in <module>
#      51
#      52
# ---> 53 get_all_name_and_detail_link()
#
# <ipython-input-33-252ebec27038> in get_all_name_and_detail_link()
#      19 def get_all_name_and_detail_link():
#      20     url= 'https://www.nba.com/players'
# ---> 21     driver.get(url)
#      22
#      23     soup = bs(driver.page_source, 'html.parser')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     428         Loads a web page in the current browser session.
#     429         """
# --> 430         self.execute(Command.GET, {'url': url})
#     431
#     432     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
# ...
